# %% [markdown]
# ### 1. Series 의 plot()

# %%
# %matplotlib inline

# %%
from pandas import Series

# %%
# 판다스 그래프 : Series의 plot() 
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])
s

s.plot(kind='bar');

# %% [markdown]
# from matplotlib import font_manager, rc
# import matplotlib.pyplot as plt
#
# plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
# rc('font', family='Malgun Gothic')

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
rc('font', family='Malgun Gothic')

# %%
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])

splot = s.plot(kind='bar');
splot.set_xlabel('데이터')
splot.set_ylabel('값')
splot.set_title('샘플데이터')
# Out:
# Text(0.5, 1.0, '샘플데이터')

# %% [markdown]
# ## 2. DataFrame 그래프

# %%
from pandas import DataFrame
import numpy as np

# 데이타프레임에서 시각화 작업
df=DataFrame(np.random.randn(10, 4),    # 난수 10개를 4번
             columns=['level','step','cnt','temp'], 
             index=np.arange(0,100,10))     # np.arange(0,100,10)
df
# Out:
#        level      step       cnt      temp
# 0  -1.199337 -1.088470 -0.482273  0.725493
# 10  0.028095  0.462619  0.783091  0.996121
# 20  0.975307  1.070978 -0.115452 -0.128478
# 30  0.148466 -0.733105  1.538773 -0.475683
# 40 -0.037331  0.287039 -0.068146  0.743872
# 50 -0.537316  0.288576  0.151139 -0.401279
# 60  0.709435  0.033102 -0.629620  0.807521
# 70 -1.250714  0.586607  0.634612  0.298566
# 80 -0.411496 -1.330045  0.910929 -0.677378
# 90  0.271258  0.747029 -1.397773 -0.642702

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# [참고] 데이타사이언스스쿨 > Pandas의 시각화 기능
#
# https://datascienceschool.net/view-notebook/372443a5d90a46429c6459bba8b4342c/
